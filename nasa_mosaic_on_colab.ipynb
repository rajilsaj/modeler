# %% [markdown]
# <a href="https://colab.research.google.com/github/rajilsaj/modeler/blob/main/nasa_mosaic_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/rajilsaj/nasa-mosaics-project.git
# Out:
# Cloning into 'nasa-mosaics-project'...
# remote: Enumerating objects: 1592, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 1592 (delta 30), reused 40 (delta 20), pack-reused 1520 (from 3)
# Receiving objects: 100% (1592/1592), 134.11 MiB | 11.69 MiB/s, done.
# Resolving deltas: 100% (464/464), done.

# %%
# %cd nasa-mosaics-project
# !ls
# Out:
# [Errno 2] No such file or directory: 'nasa-mosaics-project'
# /content/nasa-mosaics-project
#  04_feature_engineering.ipynb
#  AE_GATING_QUICK_START.md
#  AE_GATING_SLIDES.md
#  alternative_pie_chart.png
# 'Analysis and visualization script'
#  analyze_comprehensive_data.py
#  compare_datasets.py
#  comprehensive_analysis
#  comprehensive_dataset_ae_gating.py
#  comprehensive_test_analysis.py
#  comprehensive_validation_analysis.py
#  CONFERENCE_PAPER_RF_SECTION.md
#  continuous_validation_analysis
#  continuous_validation_analysis.py
# 'core pipeline scripts'
#  create_table_iii_visualization.py
#  create_table_iv_visualization.py
#  detailed_feature_analysis.png
#  evaluate_ae_gated_sliding_windows.py
# 'Evaluation Script'
#  EVALUATION_SUMMARY.md
# 'Even based script'
#  event_01_analysis.png
#  event_02_analysis.png
#  event_03_analysis.png
#  event_04_analysis.png
#  event_based_continuous_analysis
#  event_based_continuous_analysis.py
#  event_based_validation_analysis.py
# ...
